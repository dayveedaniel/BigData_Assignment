# %% [markdown]
# Test

# %%
import pandas as pd
import numpy as np
import os

# %%
path = os.path.join(os.getcwd(),'data')
print(path)
path = path.replace('scripts','')
df = pd.read_csv(f'{path}/campaigns.csv', low_memory=False)
# Out:
# /Users/dayveed/VscodeProjects/BigData_Assignment/scripts/data

# %%
df.shape
# df[['topic','campaign_type','position']]
# Out:
# (1907, 19)

# %%
df['id'].nunique()
mask = df.duplicated(subset=['id'],keep=False)
df[mask]
# Out:
#        id  campaign_type      channel                   topic  \
# 1      64           bulk  mobile_push                sale out
# 34    366           bulk        email                sale out
# 35    368           bulk  mobile_push                sale out
# 36    372           bulk  mobile_push                sale out
# 37    373           bulk  mobile_push                sale out
# 38    374           bulk        email                sale out
# 41    381           bulk        email                sale out
# 1860  366  transactional  mobile_push          order reminder
# 1867   64  transactional        email  order ready for pickup
# 1881  368  transactional  mobile_push           order created
# 1889  372  transactional  mobile_push           order created
# 1890  373  transactional  mobile_push           order shipped
# 1891  374  transactional  mobile_push  order ready for pickup
# 1893  381  transactional  mobile_push           order shipped
#
# ...
